# %% [markdown]
# ÖZKAN YAZICI İSTATİSTİK İSTATİKSEL DAĞILIMLAR ÖDEVİ

# %% [markdown]
# 1.dağılım = np.random.dağılım_adı([],[]) kodunu kullanarak, dağılım_adı yazan yere seçtiğiniz bir dağılımı ve parantez içinde [] şeklinde gösterilen boşlukları yine kendi seçiminiz doğrultusunda doldurun. Daha sonra, a) Verinin histogramını çiziniz b) Q-Q grafiğini çizip yorumlayınız.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
dağılım= np.random.normal(100,5,50)

# %%
dağılım
# Out:
# array([105.51948882,  89.77520262,  92.81115162, 105.41819339,
#         98.39526957, 102.18005228, 105.29342341, 100.03386005,
#         94.65498438, 106.53110748, 105.54201851,  99.78599323,
#         95.90706057, 106.61836971, 106.98372286,  99.66157431,
#         97.7491114 ,  94.03582134,  95.58158958, 107.03611102,
#         97.27570404,  99.62365106, 104.26896628, 100.77429045,
#         98.31071415, 104.32646617,  90.05820332, 103.67725332,
#        101.19212029,  96.01895706, 102.16300208,  90.46011957,
#         97.34723812,  96.0102343 ,  90.2043392 , 100.64591759,
#         99.98981425, 101.32150072, 107.66856285,  96.32643117,
#        105.03568546, 102.43539828, 103.0063072 ,  95.3334189 ,
#         99.68353946, 105.11832975,  95.07811263, 103.14279962,
#        104.83953235,  92.8491115 ])

# %%
plt.figure(figsize=(10,5),dpi=100)
plt.hist(dağılım)
plt.show()

# %%
örnek_veri=[5,6,12,55,74,85,120,74,9,5,
            2,1,44,55,66,15,75,36,25,12,
            59,48,55,48,95,63,21,54,85,96,
            95,47,55,21,11,33,45,85,45,25,36,
            59,48,48,58,95,65,62,69,59]

# %%
örnek_veri.sort()
dağılım.sort()

plt.figure(figsize=(10,5), dpi=100)
baslik_font = {"family":"arial","color":"darkred","weight":"bold","size":13}
eksen_font = {"family":"arial","color":"darkblue","weight":"bold","size":11}
plt.title("ÖRNEK VERİ KÜMESİ &  DAĞILIM VERİ KÜMESİ",fontdict=baslik_font)
plt.xlabel("ÖRNEK VERİ KÜMESİ", fontdict=eksen_font)
plt.ylabel("DAĞILIM VERİ KÜMESİ", fontdict=eksen_font)
plt.scatter(örnek_veri,dağılım)
plt.plot([np.min(örnek_veri),np.max(örnek_veri)],[np.min(dağılım),np.max(dağılım)], c="r")
plt.show()

# %% [markdown]
# 2.https://finance.yahoo.com/ sitesini kullanarak google şirketinin 2015-2017 yılları arasında hisse senedi fiyatlarını elde edin. Bu veriyi kullanarak hisse senedi getirisini şu formülle hesaplayın.
#
#
# <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <msub>
#     <mi>P</mi>
#     <mi>t</mi>
#   </msub>
#   <mo>&#x2212;<!-- − --></mo>
#   <msub>
#     <mi>P</mi>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mi>t</mi>
#       <mo>&#x2212;<!-- − --></mo>
#       <mn>1</mn>
#     </mrow>
#   </msub>
#   <mrow class="MJX-TeXAtom-ORD">
#     <mo>/</mo>
#   </mrow>
#   <msub>
#     <mi>P</mi>
#     <mrow class="MJX-TeXAtom-ORD">
#       <mi>t</mi>
#       <mo>&#x2212;<!-- − --></mo>
#       <mn>1</mn>
#     </mrow>
#   </msub>
# </math>
#
# (burada
# P
# t
#   t zamanındaki hisse senedi fiyatını ve
# P
# t
# −
# 1
#   ise t-1 zamanındaki hisse senedi fiyatını vermektedir). Getiriler dağılımı hangi dağılıma daha yakındır?

# %% [markdown]
# Not: https://finance.yahoo.com/ adresinden veri şu şekilde çekilir. Verilen adres tıkladıktan sonra arama bölümüne aramak istediğiniz hisse senedinin adını yazın (ör: google). Arama sonucu altta çıkan sonuca tıklayarak ilgili hisse senedine gidiniz. İlgili hisse senedinin bilgilerinin bulunduğu sayfaya geldiğinizde Historical Prices (Geçmiş veriler) sekmesine tıklayın ve ilgili tarih aralığını seçtikten sonra Apply'a tıklayın. Son olarak Download Data butonuna basarak veriyi indirin.

# %%
GOOG=pd.read_csv("GOOG.csv")
GOOG
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2014-12-31  529.795471  531.141724  524.360352  524.958740  524.958740
# 1    2015-01-02  527.561584  529.815369  522.665039  523.373108  523.373108
# 2    2015-01-05  521.827332  522.894409  511.655243  512.463013  512.463013
# 3    2015-01-06  513.589966  514.761719  499.678131  500.585632  500.585632
# 4    2015-01-07  505.611847  505.855164  498.281952  499.727997  499.727997
# ..          ...         ...         ...         ...         ...         ...
# 500  2016-12-23  790.900024  792.739990  787.280029  789.909973  789.909973
# 501  2016-12-27  790.679993  797.859985  787.656982  791.549988  791.549988
# 502  2016-12-28  793.700012  794.229980  783.200012  785.049988  785.049988
# 503  2016-12-29  783.330017  785.929993  778.919983  782.789978  782.789978
# 504  2016-12-30  782.750000  782.780029  770.409973  771.820007  771.820007
#
#       Volume
# 0    1368200
# 1    1447500
# 2    2059800
# 3    2899900
# 4    2065000
# ..       ...
# 500   623400
# 501   789100
# 502  1153800
# 503   744300
# 504  1770000
#
# [505 rows x 7 columns]

# %%
# !pip install yahoo-finance
# Out:
# Requirement already satisfied: yahoo-finance in c:\users\özkan\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: pytz in c:\users\özkan\anaconda3\lib\site-packages (from yahoo-finance) (2019.3)
# Requirement already satisfied: simplejson in c:\users\özkan\anaconda3\lib\site-packages (from yahoo-finance) (3.17.0)

# %%
# !pip install yahoofinance
# Out:
# Requirement already satisfied: yahoofinance in c:\users\özkan\anaconda3\lib\site-packages (0.0.2)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\özkan\anaconda3\lib\site-packages (from yahoofinance) (0.25.1)
# Requirement already satisfied: beautifulsoup4>=4.6.3 in c:\users\özkan\anaconda3\lib\site-packages (from yahoofinance) (4.8.0)
# Requirement already satisfied: requests>=2.20.1 in c:\users\özkan\anaconda3\lib\site-packages (from yahoofinance) (2.22.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\özkan\anaconda3\lib\site-packages (from pandas>=0.23.4->yahoofinance) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\özkan\anaconda3\lib\site-packages (from pandas>=0.23.4->yahoofinance) (2019.3)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\özkan\anaconda3\lib\site-packages (from pandas>=0.23.4->yahoofinance) (1.16.5)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\özkan\anaconda3\lib\site-packages (from beautifulsoup4>=4.6.3->yahoofinance) (1.9.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\özkan\anaconda3\lib\site-packages (from requests>=2.20.1->yahoofinance) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\özkan\anaconda3\lib\site-packages (from requests>=2.20.1->yahoofinance) (2019.9.11)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\özkan\anaconda3\lib\site-packages (from requests>=2.20.1->yahoofinance) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\özkan\anaconda3\lib\site-packages (from requests>=2.20.1->yahoofinance) (2.8)
# Requirement already satisfied: six>=1.5 in c:\users\özkan\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas>=0.23.4->yahoofinance) (1.12.0)

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\özkan\anaconda3\lib\site-packages (0.1.54)
# Requirement already satisfied: pandas>=0.24 in c:\users\özkan\anaconda3\lib\site-packages (from yfinance) (0.25.1)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\özkan\anaconda3\lib\site-packages (from yfinance) (0.0.9)
# Requirement already satisfied: numpy>=1.15 in c:\users\özkan\anaconda3\lib\site-packages (from yfinance) (1.16.5)
# Requirement already satisfied: requests>=2.20 in c:\users\özkan\anaconda3\lib\site-packages (from yfinance) (2.22.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\özkan\anaconda3\lib\site-packages (from pandas>=0.24->yfinance) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\özkan\anaconda3\lib\site-packages (from pandas>=0.24->yfinance) (2.8.0)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\özkan\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\özkan\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\özkan\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\özkan\anaconda3\lib\site-packages (from requests>=2.20->yfinance) (1.24.2)
# Requirement already satisfied: six>=1.5 in c:\users\özkan\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas>=0.24->yfinance) (1.12.0)

# %%
import yfinance as yf

# %%
google= yf.download("GOOG", start ="2015-01-01", end="2017-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
google
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-12-31  529.795471  531.141724  524.360352  524.958740  524.958740
# 2015-01-02  527.561584  529.815369  522.665039  523.373108  523.373108
# 2015-01-05  521.827332  522.894409  511.655243  512.463013  512.463013
# 2015-01-06  513.589966  514.761719  499.678131  500.585632  500.585632
# 2015-01-07  505.611847  505.855164  498.281952  499.727997  499.727997
# ...                ...         ...         ...         ...         ...
# 2016-12-23  790.900024  792.739990  787.280029  789.909973  789.909973
# 2016-12-27  790.679993  797.859985  787.656982  791.549988  791.549988
# 2016-12-28  793.700012  794.229980  783.200012  785.049988  785.049988
# 2016-12-29  783.330017  785.929993  778.919983  782.789978  782.789978
# 2016-12-30  782.750000  782.780029  770.409973  771.820007  771.820007
#
#              Volume
# Date
# 2014-12-31  1368200
# 2015-01-02  1447500
# 2015-01-05  2059800
# 2015-01-06  2899900
# 2015-01-07  2065000
# ...             ...
# 2016-12-23   623400
# 2016-12-27   789100
# 2016-12-28  1153800
# 2016-12-29   744300
# 2016-12-30  1770000
#
# [505 rows x 6 columns]

# %%
getiri = []

n=0
while n<504:
    getiri.append((google["Open"][n+1]-google["Open"][n])/google["Open"][n])
    n+=1

# %%
normal_dağlım_getiri= np.random.normal(np.mean(getiri),np.std(getiri),504)

# %%
getiri.sort()
normal_dağlım_getiri.sort()

plt.figure(figsize=(10,5),dpi=100)
eksen_font={"family":"arial","color":"darkblue","weight":"bold","size":10}
baslık_font={"family":"arial","color":"darkred","weight":"bold","size":13}
plt.title("GOOGLE HİSSE SENETİ & NORMAL DAĞILIM VERİSİ", fontdict=baslık_font)
plt.xlabel("NORMAL DAĞILIM VERİSİ",fontdict=eksen_font)
plt.ylabel("GOOGLE HİSSE SENETİ", fontdict=eksen_font)
plt.scatter(getiri,normal_dağlım_getiri)
plt.plot([np.min(getiri),np.max(getiri)],[np.min(normal_dağlım_getiri),np.max(normal_dağlım_getiri)],c="r")
plt.show()
